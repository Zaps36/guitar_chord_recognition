# %%
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
# Out:
# 2025-06-04 06:42:10.186650: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-04 06:42:10.186726: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-04 06:42:10.250101: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-04 06:42:10.369329: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-04 06:42:11.695230: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dataset_path = "" # adjust path e.g. "./Farrel/Combined_dataset""

# %% [markdown]
# <h2> loading guitar chords and validating for files with no signals

# %%
def is_invalid_audio(file_path, sr=22050, duration=2, offset=0.5):
    try:
        signal, _ = librosa.load(file_path, sr=sr, duration=duration, offset=offset)
        return signal is None or len(signal) == 0 or np.all(signal == 0)
    except Exception as e:
        print(f"Error loading {file_path}: {e.__class__.__name__} - {e}")
        return True 

labels = []

for chord_quality_dir in os.listdir(dataset_path):
    chord_quality_path = os.path.join(dataset_path, chord_quality_dir)
    if os.path.isdir(chord_quality_path):
        for chord_label_dir in os.listdir(chord_quality_path):
            chord_label_path = os.path.join(chord_quality_path, chord_label_dir)
            if os.path.isdir(chord_label_path):
                for filename in os.listdir(chord_label_path):
                    if filename.endswith(".wav"):
                        file_path = os.path.join(chord_label_path, filename)
                        if is_invalid_audio(file_path):
                            try:
                                os.remove(file_path)
                                print(f"Deleted invalid file: {file_path}")
                            except Exception as e:
                                print(f"Failed to delete {file_path}: {e}")
                        else:
                            labels.append(chord_label_dir)

print(labels)
# Out:
# ['A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'A#maj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Amaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'Bmaj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'C#maj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'Cmaj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'D#maj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Dmaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'Emaj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'F#Maj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'Fmaj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'G#maj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'Gmaj', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', 'A#maj7', ' ...

# %%
print(len(labels))
# Out:
# 1781

# %%
import collections
class_counts = collections.Counter(labels)
print(class_counts)
print(len(class_counts))
# Out:
# Counter({'Bmaj7': 63, 'Bmin7': 60, 'A#min7': 59, 'Amin7': 59, 'Cmin7': 59, 'Emin7': 56, 'Dmaj': 55, 'A#maj7': 55, 'Fmaj7': 53, 'F#min7': 53, 'Cmaj': 52, 'Gmin7': 51, 'G#maj7': 49, 'Amaj7': 48, 'Cmaj7': 47, 'F#maj7': 46, 'Fmin7': 46, 'Gmaj7': 41, 'A#maj': 38, 'Emaj': 35, 'F#Maj': 35, 'Bmaj': 33, 'Amaj': 32, 'Gmaj': 32, 'Emin': 32, 'Dmin7': 32, 'C#maj': 30, 'Emaj7': 30, 'C#min': 29, 'D#min7': 29, 'Fmaj': 28, 'Cmin': 28, 'Dmin': 28, 'Bmin': 27, 'F#min': 27, 'Gmin': 27, 'C#min7': 27, 'D#maj7': 26, 'A#min': 26, 'Fmin': 25, 'C#maj7': 24, 'Amin': 24, 'D#maj': 23, 'Dmaj7': 23, 'G#maj': 22, 'G#min7': 22, 'G#min': 19, 'D#min': 16})
# 48

# %% [markdown]
# <h3> time_stretch, white noise, and reverb augmentation of files from the internet (only run once)

# %%
# import os
# import librosa
# import numpy as np
# import soundfile as sf
# import random
# from scipy.signal import fftconvolve

# # Add slight Gaussian noise
# def add_white_noise(signal, noise_factor=0.02):
#     noise = np.random.normal(0, signal.std(), signal.size)
#     return np.clip(signal + noise * noise_factor, -1.0, 1.0)

# def time_stretch(audio, stretch_rate=1.1):
#     return librosa.effects.time_stretch(audio, rate = stretch_rate)

# # Simulated reverb using convolution
# def add_reverb(audio, sr):
#     # Create a basic impulse response with several decaying echoes
#     delay_times = [0.04, 0.08, 0.14]  # seconds
#     decay_factors = [0.6, 0.35, 0.2]

#     impulse_len = int(sr * (max(delay_times) + 0.01))
#     impulse = np.zeros(impulse_len)

#     impulse[0] = 1.0  # Direct sound
#     for delay, decay in zip(delay_times, decay_factors):
#         sample = int(sr * delay)
#         impulse[sample] = decay

#     # Apply the reverb using convolution
#     reverbed = fftconvolve(audio, impulse, mode='full')
#     return reverbed[:len(audio)]  # Trim to original length

# # Process and augment

# %%
# import os
# import librosa
# import soundfile as sf
# import random

# def augment_audio_files(chord_label_path):
#             for filename in os.listdir(chord_label_path):
#                 if filename.endswith('.wav') and not any(tag in filename for tag in ['_noisy', '_shifted', '_reverb', '_stretch']):
#                     file_path = os.path.join(chord_label_path, filename)
#                     try:
#                         y, sr = librosa.load(file_path, sr=None)

#                         # 1. Noise
#                         y_noisy = add_white_noise(y)
#                         sf.write(os.path.join(chord_label_path, filename.replace('.wav', '_noisy.wav')), y_noisy, sr)

#                         # 2. Time stretch
#                         rate = random.uniform(0.9, 1.1)
#                         y_stretched = time_stretch(y, rate)
#                         sf.write(os.path.join(chord_label_path, filename.replace('.wav', '_stretch.wav')), y_stretched, sr)

#                         # 3. Reverb
#                         y_reverb = add_reverb(y, sr)
#                         sf.write(os.path.join(chord_label_path, filename.replace('.wav', '_reverb.wav')), y_reverb, sr)

#                         print(f"Augmented: {file_path}")
#                     except Exception as e:
#                         print(f"Error processing {file_path}: {e}")
# augment_audio_files("./Guitar Dataset/Base/New Folder")
# Out:
# Augmented: ./Guitar Dataset/Base/New Folder/A_Minor2.wav
# Augmented: ./Guitar Dataset/Base/New Folder/C#_Minor.wav
# Augmented: ./Guitar Dataset/Base/New Folder/G#_Minor.wav

# %%
# augment_audio_files(dataset_path)
# Out:
# Augmented: ./Guitar Dataset/Base/Minor\A#_Minor\A#_Minor.wav
# Augmented: ./Guitar Dataset/Base/Minor\A#_Minor\A#_Minor2.wav
# Augmented: ./Guitar Dataset/Base/Minor\A_Minor\A_Minor.wav
# Augmented: ./Guitar Dataset/Base/Minor\A_Minor\A_Minor2.wav
# Augmented: ./Guitar Dataset/Base/Minor\B_Minor\B_Minor.wav
# Augmented: ./Guitar Dataset/Base/Minor\B_Minor\B_Minor2.wav
# Augmented: ./Guitar Dataset/Base/Minor\C#_Minor\C#_Major.wav
# Augmented: ./Guitar Dataset/Base/Minor\C#_Minor\C#_Major2.wav
# Augmented: ./Guitar Dataset/Base/Minor\C_Minor\C_Major.wav
# Augmented: ./Guitar Dataset/Base/Minor\C_Minor\C_Major2.wav
# Augmented: ./Guitar Dataset/Base/Minor\D#_Minor\D#_Major.wav
# Augmented: ./Guitar Dataset/Base/Minor\D#_Minor\D#_Major2.wav
# Augmented: ./Guitar Dataset/Base/Minor\D_Minor\D_Major.wav
# Augmented: ./Guitar Dataset/Base/Minor\D_Minor\D_Major2.wav
# Augmented: ./Guitar Dataset/Base/Minor\E_Minor\E_Minor.wav
# Augmented: ./Guitar Dataset/Base/Minor\E_Minor\E_Minor2.wav
# Augmented: ./Guitar Dataset/Base/Minor\F#_Minor\F#_Minor.wav
# Augmented: ./Guitar Dataset/Base/Minor\F#_Minor\F#_Minor2.wav
# Augmented: ./Guitar Dataset/Base/Minor\F_Minor\F_Minor.wav
# Augmented: ./Guitar Dataset/Base/Minor\F_Minor\F_Minor2.wav
# Augmented: ./Guitar Dataset/Base/Minor\G#_Minor\G#_Minor.wav
# Augmented: ./Guitar Dataset/Base/Minor\G#_Minor\G#_Minor2.wav
# Augmented: ./Guitar Dataset/Base/Minor\G_Minor\G_Minor.wav
# Augmented: ./Guitar Dataset/Base/Minor\G_Minor\G_Minor2.wav

# %% [markdown]
# Untuk delete augmented files **Bila Diperlukan saja**

# %%
# import os


# # Function to delete matching .wav files
# def delete_augmented_files(path):
#     deleted_files = 0
#     for root, dirs, files in os.walk(path):
#         for file in files:
#             if file.endswith(".wav") and any(tag in file for tag in ["_noisy", "_reverb", "_shifted"]):
#                 file_path = os.path.join(root, file)
#                 try:
#                     os.remove(file_path)
#                     deleted_files += 1
#                     print(f"Deleted: {file_path}")
#                 except Exception as e:
#                     print(f"Failed to delete {file_path}: {e}")
#     print(f"Total deleted in {path}: {deleted_files}")

# # Apply to both directories
# delete_augmented_files(major9_path)

# %% [markdown]
# <h2> Turning audio to Mel Spectogram, reloading all the audio

# %%
import librosa
import numpy as np
import os

def extract_mel_spectrogram(file_path, sr=22050, duration=2.5, offset=0.5, n_mels=128, max_len=200):
    try:
        signal, _ = librosa.load(file_path, sr=sr, duration=duration, offset=offset)
        if len(signal) < 2048:  # or a suitable threshold
            stretch_factor = 2048 / len(signal) + 0.1  # stretch a bit more than the bare minimum
            signal = librosa.effects.time_stretch(signal, rate=1 / stretch_factor)
            print(f"Time-stretched {file_path} by factor {stretch_factor:.2f}")
        signal = signal / (np.sqrt(np.mean(signal**2)) + 1e-6)

        mel_spec = librosa.feature.melspectrogram(y=signal, sr=sr, n_mels=n_mels, n_fft=1024)
        mel_db = librosa.power_to_db(mel_spec, ref=np.max)  # Convert to dB scale

        if np.std(mel_db) == 0:
            print(f"Skipping {file_path}: mel spectrogram has zero std.")
            return None
        mel_db = (mel_db - np.mean(mel_db)) / np.std(mel_db)  # normalize
        # Pad or truncate to ensure consistent input shape
        if mel_db.shape[1] < max_len:
            pad_width = max_len - mel_db.shape[1]
            mel_db = np.pad(mel_db, ((0, 0), (0, pad_width)), mode='constant')
        else:
            mel_db = mel_db[:, :max_len]

        return mel_db
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None


def load_dataset_from_labeled_folders(dataset_path, sr=22050, duration=2.5, offset=0.5, n_mels=128):
    X = []
    y = []
    
    for chord_quality_dir in os.listdir(dataset_path):
        chord_quality_path = os.path.join(dataset_path, chord_quality_dir)
        if os.path.isdir(chord_quality_path):
            for chord_label_dir in os.listdir(chord_quality_path):
                chord_label_path = os.path.join(chord_quality_path, chord_label_dir)
                if os.path.isdir(chord_label_path):
                    for filename in os.listdir(chord_label_path):
                        if filename.endswith(".wav"):
                            file_path = os.path.join(chord_label_path, filename)
                            label = os.path.basename(chord_label_path)
                            try:
                                mel_feat = extract_mel_spectrogram(file_path, sr=sr, duration=duration, offset=offset, n_mels=n_mels)
                                if mel_feat is not None:
                                    X.append(mel_feat)
                                    y.append(label)
                            except Exception as e:
                                print(f"Failed to process {file_path}: {e}")

    return np.array(X), np.array(y)

# %%
X, y = load_dataset_from_labeled_folders(dataset_path)

# Encode guitar labels to numeric form
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_encoded = le.fit_transform(y)

#train test split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, stratify=y_encoded, random_state=42)

#Adding new axis
X_train = X_train[..., np.newaxis]   # e.g., (samples, 128, 130, 1)
X_test = X_test[..., np.newaxis]

# One-hot encode
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# Print stats
print(f"Loaded {len(X)} samples.")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train_cat.shape)
print("Classes:", le.classes_)
# Out:
# /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1390
#   warnings.warn(
# Time-stretched ./Farrel/Combined_dataset/MAJOR/Bmaj/strum_15.wav by factor 1.57
# /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=971
#   warnings.warn(
# Time-stretched ./Farrel/Combined_dataset/MAJOR 7/A#maj7/strum_38.wav by factor 2.21
# /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1169
#   warnings.warn(
# Time-stretched ./Farrel/Combined_dataset/MINOR/Dmin/strum_9.wav by factor 1.85
# /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1213
#   warnings.warn(
# Time-stretched ./Farrel/Combined_dataset/MINOR 7/Dmin7/strum_16.wav by factor 1.79
# /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1544
#   warnings.warn(
# Time-stretched ./Farrel/Combined_dataset/MINOR 7/Fmin7/strum_12.wav by factor 1.43
# Loaded 1781 samples.
# X_train shape: (1424, 128, 200, 1)
# y_train shape: (1424, 48)
# Classes: ['A#maj' 'A#maj7' 'A#min' 'A#min7' 'Amaj' 'Amaj7' 'Amin' 'Amin7' 'Bmaj'
#  'Bmaj7' 'Bmin' 'Bmin7' 'C#maj' 'C#maj7' 'C#min' 'C#min7' 'Cmaj' 'Cmaj7'
#  'Cmin' 'Cmin7' 'D#maj' 'D#maj7' 'D#min' 'D#min7' 'Dmaj' 'Dmaj7' 'Dmin'
#  'Dmin7' 'Emaj' 'Emaj7' 'Emin' 'Emin7' 'F#Maj' 'F#maj7' 'F#min' 'F#min7'
#  'Fmaj' 'Fmaj7' 'Fmin' 'Fmin7' 'G#maj' 'G#maj7' 'G#min' 'G#min7' 'Gmaj'
#  'Gmaj7' 'Gmin' 'Gmin7']

# %%
# Shape of Output
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
num_classes = len(le.classes_)
# Out:
# X_train shape: (1424, 128, 200, 1)
# X_test shape: (357, 128, 200, 1)
# y_train shape: (1424,)
# y_test shape: (357,)

# %% [markdown]
# <h2> Model Training

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout
from tensorflow.keras.layers import Reshape, Permute, Bidirectional, LSTM, Dense
from tensorflow.keras.optimizers import Adam

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(128, 200, 1)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))   
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))   
model.add(Dropout(0.2))

model.add(Permute((2, 1, 3)))              
model.add(Reshape((50, 32 * 64)))          

model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.3))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer=Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(patience=8, restore_best_weights=True)

history = model.fit(X_train, y_train_cat,
                    validation_split=0.2,
                    epochs=50,
                    batch_size=32,
                    callbacks=[early_stop],
                    verbose=1)
# Out:
# Epoch 1/50
# 2025-06-04 06:55:00.268728: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_2/dropout_6/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 36/36 [==============================] - 20s 264ms/step - loss: 3.9163 - accuracy: 0.0263 - val_loss: 3.8743 - val_accuracy: 0.0070
# Epoch 2/50
# 36/36 [==============================] - 2s 67ms/step - loss: 3.8681 - accuracy: 0.0246 - val_loss: 3.8754 - val_accuracy: 0.0246
# Epoch 3/50
# 36/36 [==============================] - 3s 79ms/step - loss: 3.8587 - accuracy: 0.0299 - val_loss: 3.8770 - val_accuracy: 0.0246
# Epoch 4/50
# 36/36 [==============================] - 4s 117ms/step - loss: 3.8403 - accuracy: 0.0351 - val_loss: 3.8772 - val_accuracy: 0.0246
# Epoch 5/50
# 36/36 [==============================] - 4s 115ms/step - loss: 3.8221 - accuracy: 0.0369 - val_loss: 3.8820 - val_accuracy: 0.0175
# Epoch 6/50
# 36/36 [==============================] - 7s 185ms/step - loss: 3.8080 - accuracy: 0.0448 - val_loss: 3.8757 - val_accuracy: 0.0175
# Epoch 7/50
# 36/36 [==============================] - 9s 251ms/step - loss: 3.7556 - accuracy: 0.0667 - val_loss: 3.8704 - val_accuracy: 0.0175
# Epoch 8/50
# 36/36 [==============================] - 3s 85ms/step - loss: 3.7544 - accuracy: 0.0527 - val_loss: 3.8532 - val_accuracy: 0.0316
# Epoch 9/50
# 36/36 [==============================] - 3s 87ms/step - loss: 3.7210 - accuracy: 0.0588 - val_loss: 3.8345 - val_accuracy: 0.0281
# Epoch 10/50
# 36/36 [==============================] - 3s 90ms/step - loss: 3.6768 - accuracy: 0.0737 - val_loss: 3.8070 - val_accuracy: 0.0316
# Epoch 11/50
# 36/36 [==============================] - 4s 105ms/step - loss: 3.6536 - accuracy: 0.0711 - val_loss: 3.8001 - val_accuracy: 0.0491
# Epoch 12/50
# 36/36 [==============================] - 5s 146ms/step - loss: 3.6108 - accuracy: 0.0834 - val_loss: 3.7640 - val_accuracy: 0.0667
# Epoch 13/50
# 36/36 [==============================] - 5s 140ms/step - loss: 3.5577 - accuracy: 0.1018 - val_loss: 3.6968 - val_accuracy: 0.0737
# Epoch 14/50
# 36/36 [==============================] - 5s 141ms/step - loss: 3.5250 - accuracy: 0.1229 - val_loss: 3.6389 - val_accuracy: 0.1158
# Epoch 15/50
# 36/36 [==============================] - 5s 140ms/step - loss: 3.4745 - accuracy: 0.1264 - val_loss: 3.5526 - val_accuracy: 0.1684
# Epoch 16/50
# 36/36 [==============================] - 4s 121ms/step - loss: 3.4267 - accuracy: 0.1405 - val_loss: 3.4697 - val_accuracy: 0.1825
# Epoch 17/50
# 36/36 [==============================] - 4s 107ms/step - loss: 3.3749 - accuracy: 0.1457 - val_loss: 3.4060 - val_accuracy: 0.1965
# Epoch 18/50
# 36/36 [==============================] - 4s 111ms/step - loss: 3.2542 - accuracy: 0.1975 - val_loss: 3.3038 - val_accuracy: 0.2526
# Epoch 19/50
# 36/36 [==============================] - 6s 160ms/step - loss: 3.1849 - accuracy: 0.1984 - val_loss: 3.2526 - val_accuracy: 0.2561
# Epoch 20/50
# 36/36 [==============================] - 5s 138ms/step - loss: 3.1384 - accuracy: 0.2125 - val_loss: 3.1656 - val_accuracy: 0.2982
# Epoch 21/50
# 36/36 [==============================] - 4s 115ms/step - loss: 3.0540 - accuracy: 0.2327 - val_loss: 3.0432 - val_accuracy: 0.3228
# Epoch 22/50
# 36/36 [==============================] - 4s 105ms/step - loss: 2.9526 - accuracy: 0.2546 - val_loss: 2.9539 - val_accuracy: 0.3579
# Epoch 23/50
# 36/36 [==============================] - 4s 98ms/step - loss: 2.8359 - accuracy: 0.2950 - val_loss: 2.8564 - val_accuracy: 0.3789
# Epoch 24/50
# 36/36 [==============================] - 4s 98ms/step - loss: 2.7680 - accuracy: 0.3055 - val_loss: 2.7910 - val_accuracy: 0.4105
# Epoch 25/50
# 36/36 [==============================] - 4s 114ms/step - loss: 2.6981 - accuracy: 0.3310 - val_loss: 2.7262 - val_accuracy: 0.4000
# Epoch 26/50
# 36/36 [==============================] - 4s 114ms/step - loss: 2.6288 - accuracy: 0.3573 - val_loss: 2.6219 - val_accuracy: 0.4281
# Epoch 27/50
# 36/36 [==============================] - 5s 131ms/step - loss: 2.5442 - accuracy: 0.3679 - val_loss: 2.5218 - val_accuracy: 0.4596
# Epoch 28/50
# 36/36 [==============================] - 3s 94ms/step - loss: 2.4542 - accuracy: 0.3819 - val_loss: 2.4423 - val_accuracy: 0.4912
# Epoch 29/50
# 36/36 [==============================] - 3s 92ms/step - loss: 2.3870 - accuracy: 0.3995 - val_loss: 2.4044 - val_accuracy: 0.4632
# Epoch 30/50
# 36/36 [==============================] - 3s 91ms/step - loss: 2.3288 - accuracy: 0.4276 - val_loss: 2.2624 - val_accuracy: 0.5088
# Epoch 31/50
# 36/36 [==============================] - 4s 102ms/step - loss: 2.2178 - accuracy: 0.4504 - val_loss: 2.2474 - val_accuracy: 0.5053
# Epoch 32/50
# 36/36 [==============================] - 4s 111ms/step - loss: 2.1877 - accuracy: 0.4363 - val_loss: 2.1689 - val_accuracy: 0.5404
# Epoch 33/50
# 36/36 [==============================] - 5s 131ms/step - loss: 2.0868 - accuracy: 0.4741 - val_loss: 2.1133 - val_accuracy: 0.5544
# Epoch 34/50
# 36/36 [==============================] - 5s 141ms/step - loss: 1.9886 - accuracy: 0.4943 - val_loss: 1.9950 - val_accuracy: 0.5930
# Epoch 35/50
# 36/36 [==============================] - 6s 174ms/step - loss: 1.9899 - accuracy: 0.5127 - val_loss: 1.9583 - val_accuracy: 0.6000
# Epoch 36/50
# 36/36 [==============================] - 5s 144ms/step - loss: 1.9306 - accuracy: 0.5013 - val_loss: 1.9052 - val_accuracy: 0.6070
# Epoch 37/50
# 36/36 [==============================] - 5s 139ms/step - loss: 1.8226 - accuracy: 0.5461 - val_loss: 1.8415 - val_accuracy: 0.6596
# Epoch 38/50
# 36/36 [==============================] - 5s 139ms/step - loss: 1.7946 - accuracy: 0.5382 - val_loss: 1.7466 - val_accuracy: 0.6772
# Epoch 39/50
# 36/36 [==============================] - 5s 141ms/step - loss: 1.7425 - accuracy: 0.5601 - val_loss: 1.7195 - val_accuracy: 0.6772
# Epoch 40/50
# 36/36 [==============================] - 5s 142ms/step - loss: 1.6989 - accuracy: 0.5777 - val_loss: 1.6628 - val_accuracy: 0.6807
# Epoch 41/50
# 36/36 [==============================] - 5s 142ms/step - loss: 1.5895 - accuracy: 0.6023 - val_loss: 1.6365 - val_accuracy: 0.7088
# Epoch 42/50
# 36/36 [==============================] - 6s 144ms/step - loss: 1.5761 - accuracy: 0.5988 - val_loss: 1.5491 - val_accuracy: 0.7123
# Epoch 43/50
# 36/36 [==============================] - 5s 141ms/step - loss: 1.5471 - accuracy: 0.6348 - val_loss: 1.5266 - val_accuracy: 0.7123
# Epoch 44/50
# 36/36 [==============================] - 5s 134ms/step - loss: 1.4987 - accuracy: 0.6295 - val_loss: 1.4746 - val_accuracy: 0.7263
# Epoch 45/50
# 36/36 [==============================] - 5s 141ms/step - loss: 1.4792 - accuracy: 0.6269 - val_loss: 1.4565 - val_accuracy: 0.7439
# Epoch 46/50
# 36/36 [==============================] - 5s 141ms/step - loss: 1.4314 - accuracy: 0.6383 - val_loss: 1.3848 - val_accuracy: 0.7474
# Epoch 47/50
# 36/36 [==============================] - 5s 142ms/step - loss: 1.3726 - accuracy: 0.6673 - val_loss: 1.3892 - val_accuracy: 0.7368
# Epoch 48/50
# 36/36 [==============================] - 6s 174ms/step - loss: 1.3308 - accuracy: 0.6690 - val_loss: 1.3258 - val_accuracy: 0.7263
# Epoch 49/50
# 36/36 [==============================] - 5s 140ms/step - loss: 1.3209 - accuracy: 0.6760 - val_loss: 1.2650 - val_accuracy: 0.7509
# Epoch 50/50
# 36/36 [==============================] - 4s 114ms/step - loss: 1.2610 - accuracy: 0.6918 - val_loss: 1.2527 - val_accuracy: 0.7579

# %%
# Evaluate
loss, accuracy = model.evaluate(X_test, y_test_cat, verbose=0)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Test Loss: 1.1198, Test Accuracy: 0.7703

# %% [markdown]
# <h3> Save models

# %%
model.save("guitar_chord_crnn_base_model.h5")
model.save("guitar_chord_crnn_base_.keras")

import pickle
with open("label_encoder.pkl", "wb") as f:
    pickle.dump(le, f)
# Out:
# /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Collecting pandas>=1.2 (from seaborn)
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.2->seaborn)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.2->seaborn)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 11.0 MB/s eta 0:00:00a 0:00:01
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [seaborn]m3/4 [seaborn]
# Successfully installed pandas-2.2.3 pytz-2025.2 seaborn-0.13.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h3> Testing and Evaluation of Base Model

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Load the saved model
model = load_model("./guitar_chord_crnn_base_model.h5")

# 2. Evaluate on the test set
loss, accuracy = model.evaluate(X_test, y_test_cat, verbose=1)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")

# 3. Get predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test_cat, axis=1)

# 4. Print classification report
from sklearn.metrics import classification_report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=le.classes_))

# 5. (Optional) Show confusion matrix

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=le.classes_, yticklabels=le.classes_, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 12/12 [==============================] - 1s 41ms/step - loss: 1.1198 - accuracy: 0.7703
# Test Loss: 1.1198, Test Accuracy: 0.7703
# 12/12 [==============================] - 1s 21ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        A#maj       1.00      0.75      0.86         8
#       A#maj7       0.79      1.00      0.88        11
#        A#min       1.00      0.40      0.57         5
#       A#min7       0.71      0.83      0.77        12
#         Amaj       1.00      0.50      0.67         6
#        Amaj7       0.71      1.00      0.83        10
#         Amin       0.00      0.00      0.00         5
#        Amin7       0.63      1.00      0.77        12
#         Bmaj       0.86      0.86      0.86         7
#        Bmaj7       0.87      1.00      0.93        13
#         Bmin       1.00      0.20      0.33         5
#        Bmin7       0.91      0.83      0.87        12
#        C#maj       0.80      0.67      0.73         6
#       C#maj7       1.00      1.00      1.00         5
#        C#min       1.00      0.50      0.67         6
#       C#min7       1.00      1.00      1.00         5
#         Cmaj       1.00      0.64      0.78        11
#        Cmaj7       0.82      1.00      0.90         9
#         Cmin       0.75      0.50      0.60         6
#        Cmin7       0.67      1.00      0.80        12
#        D#maj       1.00      0.20      0.33         5
#       D#maj7       0.71      1.00      0.83         5
#        D#min       1.00      0.33      0.50         3
#       D#min7       1.00      1.00      1.00         6
#         Dmaj       0.79      1.00      0.88        11
#        Dmaj7       1.00      1.00      1.00         5
#         Dmin       1.00      0.50      0.67         6
#        Dmin7       0.80      0.67      0.73         6
#         Emaj       0.83      0.71      0.77         7
#        Emaj7       0.86      1.00      0.92         6
#         Emin       1.00      0.17      0.29         6
#        Emin7       0.83      0.91      0.87        11
#        F#Maj       0.71      0.71      0.71         7
#       F#maj7       0.53      1.00      0.69         9
#        F#min       0.00      0.00      0.00         5
#       F#min7       0.79      1.00      0.88        11
#         Fmaj       1.00      0.67      0.80         6
#        Fmaj7       0.61      1.00      0.76        11
#         Fmin       1.00      0.60      0.75         5
#        Fmin7       0.75      1.00      0.86         9
#        G#maj       1.00      0.50      0.67         4
#       G#maj7       0.77      1.00      0.87        10
#        G#min       0.67      0.50      0.57         4
#       G#min7       0.50      0.25      0.33         4
#         Gmaj       0.83      0.83      0.83         6
#        Gmaj7       0.33      0.25      0.29         8
#         Gmin       0.40      0.40      0.40         5
#        Gmin7       0.69      0.90      0.78        10
#
#     accuracy                           0.77       357
#    macro avg       0.79      0.70      0.70       357
# weighted avg       0.78      0.77      0.74       357
# /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# <h2> Hyperparameter Tuning

# %%
from keras_tuner import HyperModel
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout
from tensorflow.keras.layers import Reshape, Permute, Bidirectional, LSTM, Dense
from tensorflow.keras.optimizers import Adam

class CRNNHyperModel(HyperModel):
    def __init__(self, input_shape, num_classes):
        self.input_shape = input_shape
        self.num_classes = num_classes

    def build(self, hp):
        model = Sequential()

        # Tune filters
        filters = hp.Choice('conv_filters', [32, 64])
        dropout_rate = hp.Choice('dropout_rate', [0.2, 0.3])
        lstm_units = hp.Choice('lstm_units', [32, 64])
        learning_rate = hp.Choice('learning_rate', [5e-4, 1e-4])

        model.add(Conv2D(filters, (3, 3), activation='relu', padding='same', input_shape=self.input_shape))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(dropout_rate))

        model.add(Conv2D(filters * 2, (3, 3), activation='relu', padding='same'))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(dropout_rate))

        model.add(Permute((2, 1, 3)))
        model.add(Reshape((50, -1)))  # time steps = 32

        model.add(Bidirectional(LSTM(lstm_units)))
        model.add(Dropout(dropout_rate))

        model.add(Dense(64, activation='relu'))
        model.add(Dropout(dropout_rate))
        model.add(Dense(self.num_classes, activation='softmax'))

        model.compile(optimizer=Adam(learning_rate=learning_rate),
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])
        return model

# %%
from keras_tuner.tuners import RandomSearch

expanded_tuning = RandomSearch(
    CRNNHyperModel(input_shape=(128, 200, 1), num_classes=num_classes),
    objective='val_accuracy',
    max_trials=15,
    executions_per_trial=1,
    directory='crnn_tuning(3)',
    project_name='chord_recognition'
)

expanded_tuning.search(X_train, y_train_cat, epochs=50, validation_split=0.2, batch_size=32)
# Out:
# Trial 15 Complete [00h 02m 27s]
# val_accuracy: 0.9368420839309692
#
# Best val_accuracy So Far: 0.9684210419654846
# Total elapsed time: 00h 29m 40s

# %%
best_hps = expanded_tuning.get_best_hyperparameters(num_trials=1)[0]

# Print all chosen hyperparameters
print("Best hyperparameters:")
print(f"Learning rate: {best_hps.get('learning_rate')}")
print(f"Dropout rate: {best_hps.get('dropout_rate')}")
print(f"LSTM units: {best_hps.get('lstm_units')}")
print(f"Conv filters: {best_hps.get('conv_filters')}")
# Out:
# Best hyperparameters:
# Learning rate: 0.0005
# Dropout rate: 0.2
# LSTM units: 64
# Conv filters: 32

# %%
model = expanded_tuning.hypermodel.build(best_hps)

# %%
early_stop = EarlyStopping(patience=8, restore_best_weights=True)

history = model.fit(X_train, y_train_cat,
                    validation_split=0.2,
                    epochs=60,
                    batch_size=32,
                    callbacks=[early_stop],
                    verbose=1)
# Out:
# Epoch 1/60
# 36/36 [==============================] - 2s 41ms/step - loss: 3.6728 - accuracy: 0.0641 - val_loss: 3.8098 - val_accuracy: 0.0281
# Epoch 2/60
# 36/36 [==============================] - 1s 41ms/step - loss: 3.6070 - accuracy: 0.0992 - val_loss: 3.7682 - val_accuracy: 0.0596
# Epoch 3/60
# 36/36 [==============================] - 1s 41ms/step - loss: 3.5146 - accuracy: 0.1317 - val_loss: 3.7147 - val_accuracy: 0.0246
# Epoch 4/60
# 36/36 [==============================] - 1s 41ms/step - loss: 3.3873 - accuracy: 0.1449 - val_loss: 3.6531 - val_accuracy: 0.0386
# Epoch 5/60
# 36/36 [==============================] - 1s 41ms/step - loss: 3.2111 - accuracy: 0.2037 - val_loss: 3.4702 - val_accuracy: 0.1228
# Epoch 6/60
# 36/36 [==============================] - 1s 41ms/step - loss: 3.0479 - accuracy: 0.2353 - val_loss: 3.2909 - val_accuracy: 0.1404
# Epoch 7/60
# 36/36 [==============================] - 1s 41ms/step - loss: 2.8045 - accuracy: 0.3134 - val_loss: 3.0166 - val_accuracy: 0.3088
# Epoch 8/60
# 36/36 [==============================] - 3s 73ms/step - loss: 2.5930 - accuracy: 0.3872 - val_loss: 2.8103 - val_accuracy: 0.3509
# Epoch 9/60
# 36/36 [==============================] - 1s 41ms/step - loss: 2.4424 - accuracy: 0.4249 - val_loss: 2.5460 - val_accuracy: 0.4175
# Epoch 10/60
# 36/36 [==============================] - 1s 41ms/step - loss: 2.2037 - accuracy: 0.4609 - val_loss: 2.2240 - val_accuracy: 0.5263
# Epoch 11/60
# 36/36 [==============================] - 1s 41ms/step - loss: 1.9966 - accuracy: 0.5031 - val_loss: 2.0283 - val_accuracy: 0.5754
# Epoch 12/60
# 36/36 [==============================] - 2s 42ms/step - loss: 1.7672 - accuracy: 0.5716 - val_loss: 1.7721 - val_accuracy: 0.6211
# Epoch 13/60
# 36/36 [==============================] - 1s 41ms/step - loss: 1.5857 - accuracy: 0.6234 - val_loss: 1.6212 - val_accuracy: 0.6491
# Epoch 14/60
# 36/36 [==============================] - 1s 41ms/step - loss: 1.4117 - accuracy: 0.6585 - val_loss: 1.3715 - val_accuracy: 0.7474
# Epoch 15/60
# 36/36 [==============================] - 1s 41ms/step - loss: 1.2801 - accuracy: 0.6839 - val_loss: 1.1702 - val_accuracy: 0.7965
# Epoch 16/60
# 36/36 [==============================] - 1s 41ms/step - loss: 1.1494 - accuracy: 0.7384 - val_loss: 1.1091 - val_accuracy: 0.7579
# Epoch 17/60
# 36/36 [==============================] - 1s 41ms/step - loss: 1.0217 - accuracy: 0.7515 - val_loss: 0.9553 - val_accuracy: 0.8000
# Epoch 18/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.8898 - accuracy: 0.8060 - val_loss: 0.8890 - val_accuracy: 0.8667
# Epoch 19/60
# 36/36 [==============================] - 1s 40ms/step - loss: 0.8272 - accuracy: 0.8104 - val_loss: 0.8076 - val_accuracy: 0.8491
# Epoch 20/60
# 36/36 [==============================] - 1s 40ms/step - loss: 0.7792 - accuracy: 0.8235 - val_loss: 0.6408 - val_accuracy: 0.8596
# Epoch 21/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.6865 - accuracy: 0.8393 - val_loss: 0.6309 - val_accuracy: 0.8912
# Epoch 22/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.6559 - accuracy: 0.8455 - val_loss: 0.5513 - val_accuracy: 0.8842
# Epoch 23/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.5685 - accuracy: 0.8771 - val_loss: 0.5254 - val_accuracy: 0.9088
# Epoch 24/60
# 36/36 [==============================] - 1s 40ms/step - loss: 0.5201 - accuracy: 0.8946 - val_loss: 0.4834 - val_accuracy: 0.8982
# Epoch 25/60
# 36/36 [==============================] - 1s 40ms/step - loss: 0.4942 - accuracy: 0.9034 - val_loss: 0.4449 - val_accuracy: 0.9368
# Epoch 26/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.4637 - accuracy: 0.8990 - val_loss: 0.3468 - val_accuracy: 0.9404
# Epoch 27/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.4224 - accuracy: 0.9192 - val_loss: 0.3256 - val_accuracy: 0.9439
# Epoch 28/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.3690 - accuracy: 0.9280 - val_loss: 0.3126 - val_accuracy: 0.9368
# Epoch 29/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.3771 - accuracy: 0.9245 - val_loss: 0.3229 - val_accuracy: 0.9439
# Epoch 30/60
# 36/36 [==============================] - 3s 74ms/step - loss: 0.3418 - accuracy: 0.9236 - val_loss: 0.3067 - val_accuracy: 0.9649
# Epoch 31/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.3135 - accuracy: 0.9359 - val_loss: 0.2645 - val_accuracy: 0.9579
# Epoch 32/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2667 - accuracy: 0.9543 - val_loss: 0.2545 - val_accuracy: 0.9649
# Epoch 33/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2633 - accuracy: 0.9526 - val_loss: 0.2305 - val_accuracy: 0.9579
# Epoch 34/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2578 - accuracy: 0.9517 - val_loss: 0.2271 - val_accuracy: 0.9579
# Epoch 35/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2421 - accuracy: 0.9526 - val_loss: 0.2157 - val_accuracy: 0.9579
# Epoch 36/60
# 36/36 [==============================] - 2s 42ms/step - loss: 0.2496 - accuracy: 0.9500 - val_loss: 0.2052 - val_accuracy: 0.9649
# Epoch 37/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2182 - accuracy: 0.9587 - val_loss: 0.1922 - val_accuracy: 0.9789
# Epoch 38/60
# 36/36 [==============================] - 1s 40ms/step - loss: 0.2261 - accuracy: 0.9526 - val_loss: 0.2001 - val_accuracy: 0.9684
# Epoch 39/60
# 36/36 [==============================] - 1s 40ms/step - loss: 0.2227 - accuracy: 0.9552 - val_loss: 0.2003 - val_accuracy: 0.9649
# Epoch 40/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1880 - accuracy: 0.9728 - val_loss: 0.1794 - val_accuracy: 0.9825
# Epoch 41/60
# 36/36 [==============================] - 1s 40ms/step - loss: 0.1917 - accuracy: 0.9693 - val_loss: 0.1750 - val_accuracy: 0.9754
# Epoch 42/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1736 - accuracy: 0.9701 - val_loss: 0.1869 - val_accuracy: 0.9614
# Epoch 43/60
# 36/36 [==============================] - 1s 40ms/step - loss: 0.1632 - accuracy: 0.9640 - val_loss: 0.1964 - val_accuracy: 0.9649
# Epoch 44/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1581 - accuracy: 0.9737 - val_loss: 0.1881 - val_accuracy: 0.9684
# Epoch 45/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1378 - accuracy: 0.9772 - val_loss: 0.1803 - val_accuracy: 0.9719
# Epoch 46/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1357 - accuracy: 0.9763 - val_loss: 0.1729 - val_accuracy: 0.9614
# Epoch 47/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1360 - accuracy: 0.9781 - val_loss: 0.1581 - val_accuracy: 0.9649
# Epoch 48/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1367 - accuracy: 0.9728 - val_loss: 0.1643 - val_accuracy: 0.9649
# Epoch 49/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1222 - accuracy: 0.9798 - val_loss: 0.1651 - val_accuracy: 0.9614
# Epoch 50/60
# 36/36 [==============================] - 1s 40ms/step - loss: 0.1234 - accuracy: 0.9807 - val_loss: 0.1781 - val_accuracy: 0.9579
# Epoch 51/60
# 36/36 [==============================] - 1s 40ms/step - loss: 0.1340 - accuracy: 0.9754 - val_loss: 0.1611 - val_accuracy: 0.9684
# Epoch 52/60
# 36/36 [==============================] - 3s 74ms/step - loss: 0.1200 - accuracy: 0.9781 - val_loss: 0.1757 - val_accuracy: 0.9579
# Epoch 53/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1212 - accuracy: 0.9728 - val_loss: 0.1408 - val_accuracy: 0.9789
# Epoch 54/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.0963 - accuracy: 0.9895 - val_loss: 0.1458 - val_accuracy: 0.9719
# Epoch 55/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1043 - accuracy: 0.9763 - val_loss: 0.1244 - val_accuracy: 0.9789
# Epoch 56/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.0975 - accuracy: 0.9807 - val_loss: 0.1411 - val_accuracy: 0.9719
# Epoch 57/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.0902 - accuracy: 0.9868 - val_loss: 0.1361 - val_accuracy: 0.9719
# Epoch 58/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.0988 - accuracy: 0.9763 - val_loss: 0.1335 - val_accuracy: 0.9754
# Epoch 59/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1011 - accuracy: 0.9851 - val_loss: 0.1536 - val_accuracy: 0.9719
# Epoch 60/60
# 36/36 [==============================] - 1s 41ms/step - loss: 0.1013 - accuracy: 0.9789 - val_loss: 0.1646 - val_accuracy: 0.9649

# %%
# Evaluate
loss, accuracy = model.evaluate(X_test, y_test_cat, verbose=0)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Test Loss: 0.1064, Test Accuracy: 0.9692

# %%
model.save("guitar_chord_crnn_tuned_model.h5")
model.save("guitar_chord_crnn_tuned_.keras")

import pickle
with open("label_encoder_tuned.pkl", "wb") as f:
    pickle.dump(le, f)
# Out:
# /home/bryan_santosa/miniconda3/envs/machinelearning/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# <h2> Evalution of Hyper parameter modelling

# %%
# 1. Load the saved model
model = load_model("./guitar_chord_crnn_tuned_model.h5")

# 2. Evaluate on the test set
loss, accuracy = model.evaluate(X_test, y_test_cat, verbose=1)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")

# 3. Get predictions
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test_cat, axis=1)

# 4. Print classification report
from sklearn.metrics import classification_report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=le.classes_))

# 5. (Optional) Show confusion matrix

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=le.classes_, yticklabels=le.classes_, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 12/12 [==============================] - 1s 21ms/step - loss: 0.1734 - accuracy: 0.9580
# Test Loss: 0.1734, Test Accuracy: 0.9580
# 12/12 [==============================] - 1s 9ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        A#maj       1.00      1.00      1.00         8
#       A#maj7       0.92      1.00      0.96        11
#        A#min       1.00      1.00      1.00         5
#       A#min7       1.00      0.92      0.96        12
#         Amaj       1.00      1.00      1.00         6
#        Amaj7       1.00      1.00      1.00        10
#         Amin       1.00      0.80      0.89         5
#        Amin7       0.86      1.00      0.92        12
#         Bmaj       0.78      1.00      0.88         7
#        Bmaj7       1.00      1.00      1.00        13
#         Bmin       1.00      1.00      1.00         5
#        Bmin7       1.00      1.00      1.00        12
#        C#maj       1.00      1.00      1.00         6
#       C#maj7       1.00      1.00      1.00         5
#        C#min       1.00      1.00      1.00         6
#       C#min7       1.00      1.00      1.00         5
#         Cmaj       1.00      1.00      1.00        11
#        Cmaj7       1.00      1.00      1.00         9
#         Cmin       1.00      0.50      0.67         6
#        Cmin7       1.00      1.00      1.00        12
#        D#maj       1.00      1.00      1.00         5
#       D#maj7       0.83      1.00      0.91         5
#        D#min       1.00      1.00      1.00         3
#       D#min7       1.00      1.00      1.00         6
#         Dmaj       1.00      1.00      1.00        11
#        Dmaj7       1.00      1.00      1.00         5
#         Dmin       1.00      0.83      0.91         6
#        Dmin7       1.00      0.67      0.80         6
#         Emaj       1.00      1.00      1.00         7
#        Emaj7       1.00      1.00      1.00         6
#         Emin       1.00      1.00      1.00         6
#        Emin7       1.00      0.91      0.95        11
#        F#Maj       1.00      1.00      1.00         7
#       F#maj7       0.73      0.89      0.80         9
#        F#min       1.00      1.00      1.00         5
#       F#min7       1.00      1.00      1.00        11
#         Fmaj       1.00      1.00      1.00         6
#        Fmaj7       1.00      1.00      1.00        11
#         Fmin       1.00      1.00      1.00         5
#        Fmin7       0.82      1.00      0.90         9
#        G#maj       1.00      1.00      1.00         4
#       G#maj7       0.77      1.00      0.87        10
#        G#min       1.00      1.00      1.00         4
#       G#min7       1.00      0.75      0.86         4
#         Gmaj       1.00      1.00      1.00         6
#        Gmaj7       0.83      0.62      0.71         8
#         Gmin       1.00      0.80      0.89         5
#        Gmin7       1.00      1.00      1.00        10
#
#     accuracy                           0.96       357
#    macro avg       0.97      0.95      0.96       357
# weighted avg       0.96      0.96      0.96       357
